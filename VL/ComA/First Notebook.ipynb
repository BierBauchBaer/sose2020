# %% [markdown]
# # Übung 0
# Erste Eingabe <code>x+y</code>,  Taschenrechnerfunktionen:
# <blockquote>Einfache Beispiele</blockquote>

# %% [markdown]
# Autoren: <br>
# **Lukas Hantzko** , *10011048* <br>
# **Falk Trittschanke** , *10011108* <br>
# <img src="BallExp.png" width="100" height="100"></img>

# %%
3+4
# Out:
# 7

# %%
3*5
# Out:
# 15

# %%
3**2
# Out:
# 9

# %%
3^2
# Out:
# 9

# %%
e^5
# Out:
# e^5

# %% [markdown]
# That was easy <br>
# **I'm boald**
#
# ---
#
# Just like html
# <ul>
#     <li> Differentiate </li>
#     <li> Integrate </li>
# </ul>
# <a>next

# %%
u = var('u')
diff(sin(u),u)
# Out:
# cos(u)

# %% [markdown]
# Tables
# <table style="width:50%">
# <tr>
# <th> Name </th>
# <th> Address </th>
# <th> Salary </th>
# </tr>
#
# <tr>
# <td>Hanna </td>
# <td>Brisbane </td>
# <td>4000</td>
# </tr>
#
# <tr>
# <td>Adam</td>
# <td>Sydney</td>
# <td>5000</td>
# </tr>
# </table>

# %%
plot(cos, (-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive
